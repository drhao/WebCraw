# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13029781434","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":254972651,"name":"sunrisemovement/smvmt-microsite","url":"https://api.github.com/repos/sunrisemovement/smvmt-microsite"},"payload":{"push_id":5439438422,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180","before":"1cce536698afce5f99632606c6de9d34b91ed2b5","commits":[{"sha":"8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180","author":{"email":"github-actions[bot]@users.noreply.github.com","name":"github-actions[bot]"},"message":"deploy: 095b9c77742d2d0106282542fe958a3bc2e95a77","distinct":true,"url":"https://api.github.com/repos/sunrisemovement/smvmt-microsite/commits/8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180"}]},"public":true,"created_at":"2020-07-27T20:50:18Z","org":{"id":48114564,"login":"sunrisemovement","gravatar_id":"","url":"https://api.github.com/orgs/sunrisemovement","avatar_url":"https://avatars.githubusercontent.com/u/48114564?"}},{"id":"13029781419","type":"PushEvent","actor":{"id":33553428,"login":"balezz","display_login":"balezz","gravatar_id":"","url":"https://api.github.com/users/balezz","avatar_url":"https://avatars.githubusercontent.com/u/33553428?"},"repo":{"id":275191144,"name":"balezz/cv-course","url":"https://api.github.com/repos/balezz/cv-course"},"payload":{"push_id":5439438411,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"fbc6b679327964641237a733819308ef7541d203","before":"0a970862b86e254e6e5ffea4a7da0a5eef37eba7","commits":[{"sha":"fbc6b679327964641237a733819308ef7541d203","author":{"email":"balib@rambler.ru","name":"balezz"},"message":"add img1.jpg","distinct":true,"url":"https://api.github.com/repos/balezz/cv-course/commits/fbc6b679327964641237a733819308ef7541d203"}]},"public":true,"created_at":"2020-07-27T20:50:18Z"},{"id":"13029781439","type":"IssuesEvent","actor":{"id":17627350,"login":"sakthi-vetrivel","display_login":"sakthi-vetrivel","gravatar_id":"","url":"https://api.github.com/users/sakthi-vetrivel","avatar_url":"https://avatars.githubusercontent.com/u/17627350?"},"repo":{"id":150135694,"name":"Azure/OpenShift","url":"https://api.github.com/repos/Azure/OpenShift"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/Azure/OpenShift/issues/39","repository_url":"https://api.github.com/repos/Azure/OpenShift","labels_url":"https://api.github.com/repos/Azure/OpenShift/issues/39/labels{/name}","comments_url":"https://api.github.com/repos/Azure/OpenShift/issues/39/comments","events_url":"https://api.github.com/repos/Azure/OpenShift/issues/39/events","html_url":"https://github.com/Azure/OpenShift/issues/39","id":368432936,"node_id":"MDU6SXNzdWUzNjg0MzI5MzY=","number":39,"title":"Don\'t allow changing AAD app id, secret, or tenant during update call","user":{"login":"julienstroheker","id":8661347,"node_id":"MDQ6VXNlcjg2NjEzNDc=","avatar_url":"https://avatars2.githubusercontent.com/u/8661347?v=4","gravatar_id":"","url":"https://api.github.com/users/julienstroheker","html_url":"https://github.com/julienstroheker","followers_url":"https://api.github.com/users/julienstroheker/followers","following_url":"https://api.github.com/users/julienstroheker/following{/other_user}","gists_url":"https://api.github.com/users/julienstroheker/gists{/gist_id}","starred_url":"https://api.github.com/users/julienstroheker/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/julienstroheker/subscriptions","organizations_url":"https://api.github.com/users/julienstroheker/orgs","repos_url":"https://api.github.com/users/julienstroheker/repos","events_url":"https://api.github.com/users/julienstroheker/events{/privacy}","received_events_url":"https://api.github.com/users/julienstroheker/received_events","type":"User","site_admin":false},"labels":[{"id":10 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13029781434',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 254972651,
#    'name': 'sunrisemovement/smvmt-microsite',
#    'url': 'https://api.github.com/repos/sunrisemovement/smvmt-microsite'},
#   'payload': {'push_id': 5439438422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180',
#    'before': '1cce536698afce5f99632606c6de9d34b91ed2b5',
#    'commits': [{'sha': '8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'deploy: 095b9c77742d2d0106282542fe958a3bc2e95a77',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sunrisemovement/smvmt-microsite/commits/8448bae3b3e328adc63d3c6c8fb7ac7e5e9c9180'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z',
#   'org': {'id': 48114564,
#    'login': 'sunrisemovement',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sunrisemovement',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48114564?'}},
#  {'id': '13029781419',
#   'type': 'PushEvent',
#   'actor': {'id': 33553428,
#    'login': 'balezz',
#    'display_login': 'balezz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/balezz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33553428?'},
#   'repo': {'id': 275191144,
#    'name': 'balezz/cv-course',
#    'url': 'https://api.github.com/repos/balezz/cv-course'},
#   'payload': {'push_id': 5439438411,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fbc6b679327964641237a733819308ef7541d203',
#    'before': '0a970862b86e254e6e5ffea4a7da0a5eef37eba7',
#    'commits': [{'sha': 'fbc6b679327964641237a733819308ef7541d203',
#      'author': {'email': 'balib@rambler.ru', 'name': 'balezz'},
#      'message': 'add img1.jpg',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/balezz/cv-course/commits/fbc6b679327964641237a733819308ef7541d203'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781439',
#   'type': 'IssuesEvent',
#   'actor': {'id': 17627350,
#    'login': 'sakthi-vetrivel',
#    'display_login': 'sakthi-vetrivel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sakthi-vetrivel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17627350?'},
#   'repo': {'id': 150135694,
#    'name': 'Azure/OpenShift',
#    'url': 'https://api.github.com/repos/Azure/OpenShift'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/Azure/OpenShift/issues/39',
#     'repository_url': 'https://api.github.com/repos/Azure/OpenShift',
#     'labels_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/comments',
#     'events_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/events',
#     'html_url': 'https://github.com/Azure/OpenShift/issues/39',
#     'id': 368432936,
#     'node_id': 'MDU6SXNzdWUzNjg0MzI5MzY=',
#     'number': 39,
#     'title': "Don't allow changing AAD app id, secret, or tenant during update call",
#     'user': {'login': 'julienstroheker',
#      'id': 8661347,
#      'node_id': 'MDQ6VXNlcjg2NjEzNDc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/8661347?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/julienstroheker',
#      'html_url': 'https://github.com/julienstroheker',
#      'followers_url': 'https://api.github.com/users/julienstroheker/followers',
#      'following_url': 'https://api.github.com/users/julienstroheker/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/julienstroheker/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/julienstroheker/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/julienstroheker/subscriptions',
#      'organizations_url': 'https://api.github.com/users/julienstroheker/orgs',
#      'repos_url': 'https://api.github.com/users/julienstroheker/repos',
#      'events_url': 'https://api.github.com/users/julienstroheker/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/julienstroheker/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1067718766,
#       'node_id': 'MDU6TGFiZWwxMDY3NzE4NzY2',
#       'url': 'https://api.github.com/repos/Azure/OpenShift/labels/question',
#       'name': 'question',
#       'color': 'd876e3',
#       'default': True,
#       'description': 'Further information is requested'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2018-10-09T23:08:21Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'closed_at': '2020-07-27T20:50:18Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'Validate that an update/scale operation with different/changed AAD Auth profile values is not allowed.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z',
#   'org': {'id': 6844498,
#    'login': 'Azure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Azure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6844498?'}},
#  {'id': '13029781425',
#   'type': 'PushEvent',
#   'actor': {'id': 68870071,
#    'login': 'popkorn96',
#    'display_login': 'popkorn96',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/popkorn96',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68870071?'},
#   'repo': {'id': 283007859,
#    'name': 'popkorn96/method-arguments-lab-onl01-seng-ft-072720',
#    'url': 'https://api.github.com/repos/popkorn96/method-arguments-lab-onl01-seng-ft-072720'},
#   'payload': {'push_id': 5439438416,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '4bfd2be3215eec1d6074d1ef14f42a8ac4365c25',
#    'before': '5644241072b0e4b01519279251b9bbed35402f41',
#    'commits': [{'sha': '4bfd2be3215eec1d6074d1ef14f42a8ac4365c25',
#      'author': {'email': 'mpaloma2014@gmail.com',
#       'name': 'Paloma Mirta Mendez'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/popkorn96/method-arguments-lab-onl01-seng-ft-072720/commits/4bfd2be3215eec1d6074d1ef14f42a8ac4365c25'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781424',
#   'type': 'PushEvent',
#   'actor': {'id': 3457126,
#    'login': 'symeonn',
#    'display_login': 'symeonn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/symeonn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3457126?'},
#   'repo': {'id': 274384387,
#    'name': 'symeonn/grow-box-data',
#    'url': 'https://api.github.com/repos/symeonn/grow-box-data'},
#   'payload': {'push_id': 5439438409,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f1322528bb6fbed977173e58675b72d24958150f',
#    'before': 'ca3a839cf5b5ca4d7125078121893a7d45257aa7',
#    'commits': [{'sha': 'f1322528bb6fbed977173e58675b72d24958150f',
#      'author': {'email': 'symeonn@gmail.com', 'name': 'Mario'},
#      'message': 'data push',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/symeonn/grow-box-data/commits/f1322528bb6fbed977173e58675b72d24958150f'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781413',
#   'type': 'PushEvent',
#   'actor': {'id': 68858053,
#    'login': 'GeorgeTalnagi',
#    'display_login': 'GeorgeTalnagi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GeorgeTalnagi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68858053?'},
#   'repo': {'id': 283006393,
#    'name': 'GeorgeTalnagi/method-scope-lab-onl01-seng-ft-072720',
#    'url': 'https://api.github.com/repos/GeorgeTalnagi/method-scope-lab-onl01-seng-ft-072720'},
#   'payload': {'push_id': 5439438401,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '0baa1a552ebc22d1612b8936e84a1733036ee43f',
#    'before': '5e3e65153a1dde5f120606d6a88f29ee71468429',
#    'commits': [{'sha': '0baa1a552ebc22d1612b8936e84a1733036ee43f',
#      'author': {'email': 'gtalnagi@yahoo.com', 'name': 'George Talnagi'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GeorgeTalnagi/method-scope-lab-onl01-seng-ft-072720/commits/0baa1a552ebc22d1612b8936e84a1733036ee43f'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781427',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 25392995,
#    'login': 'bvtujo',
#    'display_login': 'bvtujo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bvtujo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25392995?'},
#   'repo': {'id': 202018792,
#    'name': 'aws/copilot-cli',
#    'url': 'https://api.github.com/repos/aws/copilot-cli'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/aws/copilot-cli/issues/1178',
#     'repository_url': 'https://api.github.com/repos/aws/copilot-cli',
#     'labels_url': 'https://api.github.com/repos/aws/copilot-cli/issues/1178/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aws/copilot-cli/issues/1178/comments',
#     'events_url': 'https://api.github.com/repos/aws/copilot-cli/issues/1178/events',
#     'html_url': 'https://github.com/aws/copilot-cli/issues/1178',
#     'id': 663395966,
#     'node_id': 'MDU6SXNzdWU2NjMzOTU5NjY=',
#     'number': 1178,
#     'title': 'Support RDS for storage',
#     'user': {'login': 'rothgar',
#      'id': 371796,
#      'node_id': 'MDQ6VXNlcjM3MTc5Ng==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/371796?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rothgar',
#      'html_url': 'https://github.com/rothgar',
#      'followers_url': 'https://api.github.com/users/rothgar/followers',
#      'following_url': 'https://api.github.com/users/rothgar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rothgar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rothgar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rothgar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rothgar/orgs',
#      'repos_url': 'https://api.github.com/users/rothgar/repos',
#      'events_url': 'https://api.github.com/users/rothgar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rothgar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1839717733,
#       'node_id': 'MDU6TGFiZWwxODM5NzE3NzMz',
#       'url': 'https://api.github.com/repos/aws/copilot-cli/labels/area/addon',
#       'name': 'area/addon',
#       'color': 'E8E8AC',
#       'default': False,
#       'description': 'Issues about addons.'},
#      {'id': 1785464658,
#       'node_id': 'MDU6TGFiZWwxNzg1NDY0NjU4',
#       'url': 'https://api.github.com/repos/aws/copilot-cli/labels/type/feature',
#       'name': 'type/feature',
#       'color': 'e99695',
#       'default': False,
#       'description': 'Issues that are new feature requests.'},
#      {'id': 1966489285,
#       'node_id': 'MDU6TGFiZWwxOTY2NDg5Mjg1',
#       'url': 'https://api.github.com/repos/aws/copilot-cli/labels/type/request',
#       'name': 'type/request',
#       'color': 'e99695',
#       'default': False,
#       'description': 'Issues that are created by customers.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-07-22T00:52:49Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'It would be great to also have a default template for RDS storage backend in addition to DynomoDB and S3.',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/aws/copilot-cli/issues/comments/664631214',
#     'html_url': 'https://github.com/aws/copilot-cli/issues/1178#issuecomment-664631214',
#     'issue_url': 'https://api.github.com/repos/aws/copilot-cli/issues/1178',
#     'id': 664631214,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NDYzMTIxNA==',
#     'user': {'login': 'bvtujo',
#      'id': 25392995,
#      'node_id': 'MDQ6VXNlcjI1MzkyOTk1',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/25392995?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bvtujo',
#      'html_url': 'https://github.com/bvtujo',
#      'followers_url': 'https://api.github.com/users/bvtujo/followers',
#      'following_url': 'https://api.github.com/users/bvtujo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bvtujo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bvtujo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bvtujo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bvtujo/orgs',
#      'repos_url': 'https://api.github.com/users/bvtujo/repos',
#      'events_url': 'https://api.github.com/users/bvtujo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bvtujo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-27T20:50:18Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'author_association': 'MEMBER',
#     'body': 'Hi @jonchase we\'re considering how to do this safely in #1172. Your use case seems fairly common and we need to find a better story for resource names, since customers may want to retain data but start with a "fresh" bucket on a new version or iteration of the service. \r\n\r\nWe\'re considering making the bucket or table name into a fully optional parameter, which would allow us to rely on CF to generate random resource names and avoid naming collisions. \r\n\r\nWe set the deletion policy to \'retain\' by default because we don\'t want folks to accidentally lose data by tearing down an S3 bucket with "svc delete" before backing things up. Does that make sense? ',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z',
#   'org': {'id': 2232217,
#    'login': 'aws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?'}},
#  {'id': '13029781398',
#   'type': 'PushEvent',
#   'actor': {'id': 21104,
#    'login': 'miry',
#    'display_login': 'miry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21104?'},
#   'repo': {'id': 7983424,
#    'name': 'miry/online_games_bots',
#    'url': 'https://api.github.com/repos/miry/online_games_bots'},
#   'payload': {'push_id': 5439438400,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5c67aa1e83c76bdcd881d2cc76d0ddc318b69146',
#    'before': '54ed3be04c423da53d438f1ca28a66e7efe76be9',
#    'commits': [{'sha': '5c67aa1e83c76bdcd881d2cc76d0ddc318b69146',
#      'author': {'email': 'miry.sof@gmail.com', 'name': 'Michael Nikitochkin'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/miry/online_games_bots/commits/5c67aa1e83c76bdcd881d2cc76d0ddc318b69146'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781391',
#   'type': 'PushEvent',
#   'actor': {'id': 68827273,
#    'login': 'purrfectgf',
#    'display_login': 'purrfectgf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/purrfectgf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68827273?'},
#   'repo': {'id': 282733726,
#    'name': 'purrfectgf/cartoon-hero',
#    'url': 'https://api.github.com/repos/purrfectgf/cartoon-hero'},
#   'payload': {'push_id': 5439438387,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9845b0c71de88dc490baaf62a26201d97dbf1e07',
#    'before': 'df4a1bdee75c27eec6e19a76ebaaa73027ad6da1',
#    'commits': [{'sha': '9845b0c71de88dc490baaf62a26201d97dbf1e07',
#      'author': {'email': 'classichumanbeing123@gmail.com', 'name': 'Fauziya'},
#      'message': 'Created a CSS test html page and CSS file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/purrfectgf/cartoon-hero/commits/9845b0c71de88dc490baaf62a26201d97dbf1e07'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781384',
#   'type': 'PushEvent',
#   'actor': {'id': 36913957,
#    'login': 'ddeveloper72',
#    'display_login': 'ddeveloper72',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ddeveloper72',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36913957?'},
#   'repo': {'id': 281798058,
#    'name': 'ddeveloper72/movie-rater',
#    'url': 'https://api.github.com/repos/ddeveloper72/movie-rater'},
#   'payload': {'push_id': 5439438398,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/user-rating-system',
#    'head': '978d56bcd0ac24d6a7caaf35bfccdae3004e14e9',
#    'before': 'a3c5daf8cd043ed1236442a8d27a5da51d0382b1',
#    'commits': [{'sha': 'c8b1b0f73a3fd2c562fc0be7d266c8640cbb8c25',
#      'author': {'email': 'duncan.niamh@gmail.com', 'name': 'ddeveloper72'},
#      'message': 'added notes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ddeveloper72/movie-rater/commits/c8b1b0f73a3fd2c562fc0be7d266c8640cbb8c25'},
#     {'sha': 'e69e1673ace2f09ecb9df5b11a7c54e8022804ed',
#      'author': {'email': 'duncan.niamh@gmail.com', 'name': 'ddeveloper72'},
#      'message': 'added h2 font size',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ddeveloper72/movie-rater/commits/e69e1673ace2f09ecb9df5b11a7c54e8022804ed'},
#     {'sha': '978d56bcd0ac24d6a7caaf35bfccdae3004e14e9',
#      'author': {'email': 'duncan.niamh@gmail.com', 'name': 'ddeveloper72'},
#      'message': 'refactored css classes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ddeveloper72/movie-rater/commits/978d56bcd0ac24d6a7caaf35bfccdae3004e14e9'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781373',
#   'type': 'PushEvent',
#   'actor': {'id': 96966,
#    'login': 'fellz',
#    'display_login': 'fellz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fellz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96966?'},
#   'repo': {'id': 279328676,
#    'name': 'fellz/mesto.platform',
#    'url': 'https://api.github.com/repos/fellz/mesto.platform'},
#   'payload': {'push_id': 5439438385,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '371e62d0dca799983d01f552a8eab914c675f1c5',
#    'before': 'f45a459754af3e0773283153d81b52a1f3bb61ef',
#    'commits': [{'sha': '371e62d0dca799983d01f552a8eab914c675f1c5',
#      'author': {'email': 'felixcon@gmail.com', 'name': 'Roman'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fellz/mesto.platform/commits/371e62d0dca799983d01f552a8eab914c675f1c5'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781381',
#   'type': 'PushEvent',
#   'actor': {'id': 37654570,
#    'login': 'Hafiz-Suhaib',
#    'display_login': 'Hafiz-Suhaib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hafiz-Suhaib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37654570?'},
#   'repo': {'id': 281463959,
#    'name': 'waleed3276/GitOlaWakee',
#    'url': 'https://api.github.com/repos/waleed3276/GitOlaWakee'},
#   'payload': {'push_id': 5439438394,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a65a42dc6ede6a098aa5ad65d0e631d4d01c2fa6',
#    'before': '3b837b54900452259820681c8d7094e6f3968f9a',
#    'commits': [{'sha': 'a65a42dc6ede6a098aa5ad65d0e631d4d01c2fa6',
#      'author': {'email': 'hafizsuhaib25@outlook.com',
#       'name': 'Hafiz M Suhaib'},
#      'message': 'new changes in post apis',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/waleed3276/GitOlaWakee/commits/a65a42dc6ede6a098aa5ad65d0e631d4d01c2fa6'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781402',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 227387290,
#    'name': '3Golds/kubespray',
#    'url': 'https://api.github.com/repos/3Golds/kubespray'},
#   'payload': {'action': 'opened',
#    'number': 280,
#    'pull_request': {'url': 'https://api.github.com/repos/3Golds/kubespray/pulls/280',
#     'id': 457395196,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDU3Mzk1MTk2',
#     'html_url': 'https://github.com/3Golds/kubespray/pull/280',
#     'diff_url': 'https://github.com/3Golds/kubespray/pull/280.diff',
#     'patch_url': 'https://github.com/3Golds/kubespray/pull/280.patch',
#     'issue_url': 'https://api.github.com/repos/3Golds/kubespray/issues/280',
#     'number': 280,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] master from kubernetes-sigs:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2020-07-27T20:50:18Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/3Golds/kubespray/pulls/280/commits',
#     'review_comments_url': 'https://api.github.com/repos/3Golds/kubespray/pulls/280/comments',
#     'review_comment_url': 'https://api.github.com/repos/3Golds/kubespray/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/3Golds/kubespray/issues/280/comments',
#     'statuses_url': 'https://api.github.com/repos/3Golds/kubespray/statuses/b8c4bd200e7afe3a54f16488862974037232617e',
#     'head': {'label': 'kubernetes-sigs:master',
#      'ref': 'master',
#      'sha': 'b8c4bd200e7afe3a54f16488862974037232617e',
#      'user': {'login': 'kubernetes-sigs',
#       'id': 36015203,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MDE1MjAz',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/36015203?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kubernetes-sigs',
#       'html_url': 'https://github.com/kubernetes-sigs',
#       'followers_url': 'https://api.github.com/users/kubernetes-sigs/followers',
#       'following_url': 'https://api.github.com/users/kubernetes-sigs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kubernetes-sigs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kubernetes-sigs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kubernetes-sigs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kubernetes-sigs/orgs',
#       'repos_url': 'https://api.github.com/users/kubernetes-sigs/repos',
#       'events_url': 'https://api.github.com/users/kubernetes-sigs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kubernetes-sigs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 43613404,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MzYxMzQwNA==',
#       'name': 'kubespray',
#       'full_name': 'kubernetes-sigs/kubespray',
#       'private': False,
#       'owner': {'login': 'kubernetes-sigs',
#        'id': 36015203,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MDE1MjAz',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/36015203?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kubernetes-sigs',
#        'html_url': 'https://github.com/kubernetes-sigs',
#        'followers_url': 'https://api.github.com/users/kubernetes-sigs/followers',
#        'following_url': 'https://api.github.com/users/kubernetes-sigs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kubernetes-sigs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kubernetes-sigs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kubernetes-sigs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kubernetes-sigs/orgs',
#        'repos_url': 'https://api.github.com/users/kubernetes-sigs/repos',
#        'events_url': 'https://api.github.com/users/kubernetes-sigs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kubernetes-sigs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kubernetes-sigs/kubespray',
#       'description': 'Deploy a Production Ready Kubernetes Cluster',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kubernetes-sigs/kubespray',
#       'forks_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/forks',
#       'keys_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/teams',
#       'hooks_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/events',
#       'assignees_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/tags',
#       'blobs_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/languages',
#       'stargazers_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/subscription',
#       'commits_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/merges',
#       'archive_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/downloads',
#       'issues_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kubernetes-sigs/kubespray/deployments',
#       'created_at': '2015-10-03T20:18:11Z',
#       'updated_at': '2020-07-27T14:44:25Z',
#       'pushed_at': '2020-07-27T17:46:16Z',
#       'git_url': 'git://github.com/kubernetes-sigs/kubespray.git',
#       'ssh_url': 'git@github.com:kubernetes-sigs/kubespray.git',
#       'clone_url': 'https://github.com/kubernetes-sigs/kubespray.git',
#       'svn_url': 'https://github.com/kubernetes-sigs/kubespray',
#       'homepage': '',
#       'size': 13621,
#       'stargazers_count': 9092,
#       'watchers_count': 9092,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 3795,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 209,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 3795,
#       'open_issues': 209,
#       'watchers': 9092,
#       'default_branch': 'master'}},
#     'base': {'label': '3Golds:master',
#      'ref': 'master',
#      'sha': 'b680cdd0e472608ae0f161d7f6da1799532180cc',
#      'user': {'login': '3Golds',
#       'id': 20660115,
#       'node_id': 'MDQ6VXNlcjIwNjYwMTE1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/20660115?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/3Golds',
#       'html_url': 'https://github.com/3Golds',
#       'followers_url': 'https://api.github.com/users/3Golds/followers',
#       'following_url': 'https://api.github.com/users/3Golds/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/3Golds/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/3Golds/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/3Golds/subscriptions',
#       'organizations_url': 'https://api.github.com/users/3Golds/orgs',
#       'repos_url': 'https://api.github.com/users/3Golds/repos',
#       'events_url': 'https://api.github.com/users/3Golds/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/3Golds/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 227387290,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjczODcyOTA=',
#       'name': 'kubespray',
#       'full_name': '3Golds/kubespray',
#       'private': False,
#       'owner': {'login': '3Golds',
#        'id': 20660115,
#        'node_id': 'MDQ6VXNlcjIwNjYwMTE1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/20660115?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/3Golds',
#        'html_url': 'https://github.com/3Golds',
#        'followers_url': 'https://api.github.com/users/3Golds/followers',
#        'following_url': 'https://api.github.com/users/3Golds/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/3Golds/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/3Golds/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/3Golds/subscriptions',
#        'organizations_url': 'https://api.github.com/users/3Golds/orgs',
#        'repos_url': 'https://api.github.com/users/3Golds/repos',
#        'events_url': 'https://api.github.com/users/3Golds/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/3Golds/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/3Golds/kubespray',
#       'description': 'Deploy a Production Ready Kubernetes Cluster',
#       'fork': True,
#       'url': 'https://api.github.com/repos/3Golds/kubespray',
#       'forks_url': 'https://api.github.com/repos/3Golds/kubespray/forks',
#       'keys_url': 'https://api.github.com/repos/3Golds/kubespray/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/3Golds/kubespray/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/3Golds/kubespray/teams',
#       'hooks_url': 'https://api.github.com/repos/3Golds/kubespray/hooks',
#       'issue_events_url': 'https://api.github.com/repos/3Golds/kubespray/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/3Golds/kubespray/events',
#       'assignees_url': 'https://api.github.com/repos/3Golds/kubespray/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/3Golds/kubespray/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/3Golds/kubespray/tags',
#       'blobs_url': 'https://api.github.com/repos/3Golds/kubespray/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/3Golds/kubespray/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/3Golds/kubespray/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/3Golds/kubespray/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/3Golds/kubespray/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/3Golds/kubespray/languages',
#       'stargazers_url': 'https://api.github.com/repos/3Golds/kubespray/stargazers',
#       'contributors_url': 'https://api.github.com/repos/3Golds/kubespray/contributors',
#       'subscribers_url': 'https://api.github.com/repos/3Golds/kubespray/subscribers',
#       'subscription_url': 'https://api.github.com/repos/3Golds/kubespray/subscription',
#       'commits_url': 'https://api.github.com/repos/3Golds/kubespray/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/3Golds/kubespray/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/3Golds/kubespray/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/3Golds/kubespray/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/3Golds/kubespray/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/3Golds/kubespray/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/3Golds/kubespray/merges',
#       'archive_url': 'https://api.github.com/repos/3Golds/kubespray/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/3Golds/kubespray/downloads',
#       'issues_url': 'https://api.github.com/repos/3Golds/kubespray/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/3Golds/kubespray/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/3Golds/kubespray/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/3Golds/kubespray/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/3Golds/kubespray/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/3Golds/kubespray/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/3Golds/kubespray/deployments',
#       'created_at': '2019-12-11T14:38:05Z',
#       'updated_at': '2020-07-27T12:50:27Z',
#       'pushed_at': '2020-07-27T12:50:21Z',
#       'git_url': 'git://github.com/3Golds/kubespray.git',
#       'ssh_url': 'git@github.com:3Golds/kubespray.git',
#       'clone_url': 'https://github.com/3Golds/kubespray.git',
#       'svn_url': 'https://github.com/3Golds/kubespray',
#       'homepage': '',
#       'size': 13480,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/3Golds/kubespray/pulls/280'},
#      'html': {'href': 'https://github.com/3Golds/kubespray/pull/280'},
#      'issue': {'href': 'https://api.github.com/repos/3Golds/kubespray/issues/280'},
#      'comments': {'href': 'https://api.github.com/repos/3Golds/kubespray/issues/280/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/3Golds/kubespray/pulls/280/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/3Golds/kubespray/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/3Golds/kubespray/pulls/280/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/3Golds/kubespray/statuses/b8c4bd200e7afe3a54f16488862974037232617e'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 189,
#     'deletions': 179,
#     'changed_files': 76}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781387',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 17627350,
#    'login': 'sakthi-vetrivel',
#    'display_login': 'sakthi-vetrivel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sakthi-vetrivel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17627350?'},
#   'repo': {'id': 150135694,
#    'name': 'Azure/OpenShift',
#    'url': 'https://api.github.com/repos/Azure/OpenShift'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Azure/OpenShift/issues/39',
#     'repository_url': 'https://api.github.com/repos/Azure/OpenShift',
#     'labels_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/comments',
#     'events_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39/events',
#     'html_url': 'https://github.com/Azure/OpenShift/issues/39',
#     'id': 368432936,
#     'node_id': 'MDU6SXNzdWUzNjg0MzI5MzY=',
#     'number': 39,
#     'title': "Don't allow changing AAD app id, secret, or tenant during update call",
#     'user': {'login': 'julienstroheker',
#      'id': 8661347,
#      'node_id': 'MDQ6VXNlcjg2NjEzNDc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/8661347?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/julienstroheker',
#      'html_url': 'https://github.com/julienstroheker',
#      'followers_url': 'https://api.github.com/users/julienstroheker/followers',
#      'following_url': 'https://api.github.com/users/julienstroheker/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/julienstroheker/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/julienstroheker/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/julienstroheker/subscriptions',
#      'organizations_url': 'https://api.github.com/users/julienstroheker/orgs',
#      'repos_url': 'https://api.github.com/users/julienstroheker/repos',
#      'events_url': 'https://api.github.com/users/julienstroheker/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/julienstroheker/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1067718766,
#       'node_id': 'MDU6TGFiZWwxMDY3NzE4NzY2',
#       'url': 'https://api.github.com/repos/Azure/OpenShift/labels/question',
#       'name': 'question',
#       'color': 'd876e3',
#       'default': True,
#       'description': 'Further information is requested'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2018-10-09T23:08:21Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'closed_at': '2020-07-27T20:50:18Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'Validate that an update/scale operation with different/changed AAD Auth profile values is not allowed.',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/Azure/OpenShift/issues/comments/664631212',
#     'html_url': 'https://github.com/Azure/OpenShift/issues/39#issuecomment-664631212',
#     'issue_url': 'https://api.github.com/repos/Azure/OpenShift/issues/39',
#     'id': 664631212,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NDYzMTIxMg==',
#     'user': {'login': 'sakthi-vetrivel',
#      'id': 17627350,
#      'node_id': 'MDQ6VXNlcjE3NjI3MzUw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/17627350?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sakthi-vetrivel',
#      'html_url': 'https://github.com/sakthi-vetrivel',
#      'followers_url': 'https://api.github.com/users/sakthi-vetrivel/followers',
#      'following_url': 'https://api.github.com/users/sakthi-vetrivel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sakthi-vetrivel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sakthi-vetrivel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sakthi-vetrivel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sakthi-vetrivel/orgs',
#      'repos_url': 'https://api.github.com/users/sakthi-vetrivel/repos',
#      'events_url': 'https://api.github.com/users/sakthi-vetrivel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sakthi-vetrivel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-27T20:50:18Z',
#     'updated_at': '2020-07-27T20:50:18Z',
#     'author_association': 'COLLABORATOR',
#     'body': "Closing this issue as it's gone stale.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z',
#   'org': {'id': 6844498,
#    'login': 'Azure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Azure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6844498?'}},
#  {'id': '13029781386',
#   'type': 'PushEvent',
#   'actor': {'id': 65616263,
#    'login': 'tbutler1132',
#    'display_login': 'tbutler1132',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tbutler1132',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65616263?'},
#   'repo': {'id': 282029067,
#    'name': 'tbutler1132/advanced-hashes-hashketball-nyc01-seng-ft-080320',
#    'url': 'https://api.github.com/repos/tbutler1132/advanced-hashes-hashketball-nyc01-seng-ft-080320'},
#   'payload': {'push_id': 5439438389,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'efc502c79503b07b43d014b0ac2648415ca589c5',
#    'before': '28bce81440dca5378c32e9f75c051bf7f4c60670',
#    'commits': [{'sha': 'efc502c79503b07b43d014b0ac2648415ca589c5',
#      'author': {'email': 'tbutler1132@gmail.com',
#       'name': 'artificial-composition-7121'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tbutler1132/advanced-hashes-hashketball-nyc01-seng-ft-080320/commits/efc502c79503b07b43d014b0ac2648415ca589c5'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781365',
#   'type': 'CreateEvent',
#   'actor': {'id': 64600275,
#    'login': 'tuliocharles',
#    'display_login': 'tuliocharles',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuliocharles',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64600275?'},
#   'repo': {'id': 283013349,
#    'name': 'tuliocharles/hellow-world',
#    'url': 'https://api.github.com/repos/tuliocharles/hellow-world'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'first github project',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781323',
#   'type': 'PushEvent',
#   'actor': {'id': 801853,
#    'login': 'Sikerdebaard',
#    'display_login': 'Sikerdebaard',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sikerdebaard',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/801853?'},
#   'repo': {'id': 251383371,
#    'name': 'Sikerdebaard/dutchcovid19data',
#    'url': 'https://api.github.com/repos/Sikerdebaard/dutchcovid19data'},
#   'payload': {'push_id': 5439438352,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1c7014faf4dc9f0911dd966ec63e4a538b944aea',
#    'before': '1ed12a96d2f3d8e3e5b4cdc314deabf1b1890de9',
#    'commits': [{'sha': '1c7014faf4dc9f0911dd966ec63e4a538b944aea',
#      'author': {'email': 'tphil@bigr-ragnaros.erasmusmc.nl',
#       'name': 'Thomas Phil'},
#      'message': 'automatic update datafiles',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sikerdebaard/dutchcovid19data/commits/1c7014faf4dc9f0911dd966ec63e4a538b944aea'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781336',
#   'type': 'PushEvent',
#   'actor': {'id': 38165949,
#    'login': 'jeast00',
#    'display_login': 'jeast00',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jeast00',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38165949?'},
#   'repo': {'id': 283007690,
#    'name': 'jeast00/sinatra-integrating-models-walkthrough-onl01-seng-pt-050420',
#    'url': 'https://api.github.com/repos/jeast00/sinatra-integrating-models-walkthrough-onl01-seng-pt-050420'},
#   'payload': {'push_id': 5439438371,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '95c27fcc714f7acd10e4c6dfe357b27301a4d98c',
#    'before': 'd15d5a66831cb607a0fb5ff22e1d392f7c74992a',
#    'commits': [{'sha': '95c27fcc714f7acd10e4c6dfe357b27301a4d98c',
#      'author': {'email': 'jonathan_east@ymail.com', 'name': 'Jonathan East'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jeast00/sinatra-integrating-models-walkthrough-onl01-seng-pt-050420/commits/95c27fcc714f7acd10e4c6dfe357b27301a4d98c'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:18Z'},
#  {'id': '13029781356',
#   'type': 'PushEvent',
#   'actor': {'id': 46307699,
#    'login': 'wetogethercppenry',
#    'display_login': 'wetogethercppenry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wetogethercppenry',
# ...
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5MjcwOTE5',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/39270919?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/PrefectHQ',
#        'html_url': 'https://github.com/PrefectHQ',
#        'followers_url': 'https://api.github.com/users/PrefectHQ/followers',
#        'following_url': 'https://api.github.com/users/PrefectHQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/PrefectHQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/PrefectHQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/PrefectHQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/PrefectHQ/orgs',
#        'repos_url': 'https://api.github.com/users/PrefectHQ/repos',
#        'events_url': 'https://api.github.com/users/PrefectHQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/PrefectHQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/PrefectHQ/prefect',
#       'description': 'A modern data workflow platform',
#       'fork': False,
#       'url': 'https://api.github.com/repos/PrefectHQ/prefect',
#       'forks_url': 'https://api.github.com/repos/PrefectHQ/prefect/forks',
#       'keys_url': 'https://api.github.com/repos/PrefectHQ/prefect/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/PrefectHQ/prefect/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/PrefectHQ/prefect/teams',
#       'hooks_url': 'https://api.github.com/repos/PrefectHQ/prefect/hooks',
#       'issue_events_url': 'https://api.github.com/repos/PrefectHQ/prefect/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/PrefectHQ/prefect/events',
#       'assignees_url': 'https://api.github.com/repos/PrefectHQ/prefect/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/PrefectHQ/prefect/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/PrefectHQ/prefect/tags',
#       'blobs_url': 'https://api.github.com/repos/PrefectHQ/prefect/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/PrefectHQ/prefect/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/PrefectHQ/prefect/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/PrefectHQ/prefect/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/PrefectHQ/prefect/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/PrefectHQ/prefect/languages',
#       'stargazers_url': 'https://api.github.com/repos/PrefectHQ/prefect/stargazers',
#       'contributors_url': 'https://api.github.com/repos/PrefectHQ/prefect/contributors',
#       'subscribers_url': 'https://api.github.com/repos/PrefectHQ/prefect/subscribers',
#       'subscription_url': 'https://api.github.com/repos/PrefectHQ/prefect/subscription',
#       'commits_url': 'https://api.github.com/repos/PrefectHQ/prefect/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/PrefectHQ/prefect/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/PrefectHQ/prefect/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/PrefectHQ/prefect/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PrefectHQ/prefect/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/PrefectHQ/prefect/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/PrefectHQ/prefect/merges',
#       'archive_url': 'https://api.github.com/repos/PrefectHQ/prefect/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/PrefectHQ/prefect/downloads',
#       'issues_url': 'https://api.github.com/repos/PrefectHQ/prefect/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/PrefectHQ/prefect/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/PrefectHQ/prefect/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/PrefectHQ/prefect/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/PrefectHQ/prefect/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/PrefectHQ/prefect/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/PrefectHQ/prefect/deployments',
#       'created_at': '2018-06-29T21:59:26Z',
#       'updated_at': '2020-07-27T20:28:32Z',
#       'pushed_at': '2020-07-27T20:50:16Z',
#       'git_url': 'git://github.com/PrefectHQ/prefect.git',
#       'ssh_url': 'git@github.com:PrefectHQ/prefect.git',
#       'clone_url': 'https://github.com/PrefectHQ/prefect.git',
#       'svn_url': 'https://github.com/PrefectHQ/prefect',
#       'homepage': 'https://prefect.io',
#       'size': 37407,
#       'stargazers_count': 2980,
#       'watchers_count': 2980,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 266,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 189,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 266,
#       'open_issues': 189,
#       'watchers': 2980,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/pulls/3030'},
#      'html': {'href': 'https://github.com/PrefectHQ/prefect/pull/3030'},
#      'issue': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/issues/3030'},
#      'comments': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/issues/3030/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/pulls/3030/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/pulls/3030/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/PrefectHQ/prefect/statuses/fe4f2d3dbfec080518e9d4e77edfad8ec16fb9dc'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'joshmeek',
#      'id': 40716964,
#      'node_id': 'MDQ6VXNlcjQwNzE2OTY0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/40716964?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/joshmeek',
#      'html_url': 'https://github.com/joshmeek',
#      'followers_url': 'https://api.github.com/users/joshmeek/followers',
#      'following_url': 'https://api.github.com/users/joshmeek/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/joshmeek/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/joshmeek/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/joshmeek/subscriptions',
#      'organizations_url': 'https://api.github.com/users/joshmeek/orgs',
#      'repos_url': 'https://api.github.com/users/joshmeek/repos',
#      'events_url': 'https://api.github.com/users/joshmeek/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/joshmeek/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 4,
#     'review_comments': 3,
#     'maintainer_can_modify': False,
#     'commits': 15,
#     'additions': 151,
#     'deletions': 31,
#     'changed_files': 13}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:17Z',
#   'org': {'id': 39270919,
#    'login': 'PrefectHQ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PrefectHQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39270919?'}},
#  {'id': '13029781298',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 30189103,
#    'login': 'openshift-ci-robot',
#    'display_login': 'openshift-ci-robot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openshift-ci-robot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30189103?'},
#   'repo': {'id': 161687402,
#    'name': 'openshift/ocs-operator',
#    'url': 'https://api.github.com/repos/openshift/ocs-operator'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/openshift/ocs-operator/issues/646',
#     'repository_url': 'https://api.github.com/repos/openshift/ocs-operator',
#     'labels_url': 'https://api.github.com/repos/openshift/ocs-operator/issues/646/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/openshift/ocs-operator/issues/646/comments',
#     'events_url': 'https://api.github.com/repos/openshift/ocs-operator/issues/646/events',
#     'html_url': 'https://github.com/openshift/ocs-operator/pull/646',
#     'id': 664418879,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDU1NjYxNzg5',
#     'number': 646,
#     'title': 'Refactor: Get rid of pkg/deploy-manager',
#     'user': {'login': 'rajatsingh25aug',
#      'id': 17253992,
#      'node_id': 'MDQ6VXNlcjE3MjUzOTky',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/17253992?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rajatsingh25aug',
#      'html_url': 'https://github.com/rajatsingh25aug',
#      'followers_url': 'https://api.github.com/users/rajatsingh25aug/followers',
#      'following_url': 'https://api.github.com/users/rajatsingh25aug/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rajatsingh25aug/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rajatsingh25aug/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rajatsingh25aug/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rajatsingh25aug/orgs',
#      'repos_url': 'https://api.github.com/users/rajatsingh25aug/repos',
#      'events_url': 'https://api.github.com/users/rajatsingh25aug/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rajatsingh25aug/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-07-23T12:04:46Z',
#     'updated_at': '2020-07-27T20:50:17Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/openshift/ocs-operator/pulls/646',
#      'html_url': 'https://github.com/openshift/ocs-operator/pull/646',
#      'diff_url': 'https://github.com/openshift/ocs-operator/pull/646.diff',
#      'patch_url': 'https://github.com/openshift/ocs-operator/pull/646.patch'},
#     'body': 'Removed `pkg/deploy-manager` and moved all the files into `functests` in a relevant manner.\r\n\r\n[JIRA LINK ](https://issues.redhat.com/browse/RHSTOR-1127).\r\n\r\nSigned-off-by: RAJAT SINGH <rajasing@redhat.com>',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/openshift/ocs-operator/issues/comments/664631208',
#     'html_url': 'https://github.com/openshift/ocs-operator/pull/646#issuecomment-664631208',
#     'issue_url': 'https://api.github.com/repos/openshift/ocs-operator/issues/646',
#     'id': 664631208,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NDYzMTIwOA==',
#     'user': {'login': 'openshift-ci-robot',
#      'id': 30189103,
#      'node_id': 'MDQ6VXNlcjMwMTg5MTAz',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/30189103?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/openshift-ci-robot',
#      'html_url': 'https://github.com/openshift-ci-robot',
#      'followers_url': 'https://api.github.com/users/openshift-ci-robot/followers',
#      'following_url': 'https://api.github.com/users/openshift-ci-robot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/openshift-ci-robot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/openshift-ci-robot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/openshift-ci-robot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/openshift-ci-robot/orgs',
#      'repos_url': 'https://api.github.com/users/openshift-ci-robot/repos',
#      'events_url': 'https://api.github.com/users/openshift-ci-robot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/openshift-ci-robot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-27T20:50:17Z',
#     'updated_at': '2020-07-27T20:50:17Z',
#     'author_association': 'NONE',
#     'body': '@rajatsingh25aug: The following tests **failed**, say `/retest` to rerun all failed tests:\n\nTest name | Commit | Details | Rerun command\n--- | --- | --- | ---\nci/prow/ocs-operator-e2e-aws | aadb46a0a2b99f05c136f987f31754e1e1c699e1 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/openshift_ocs-operator/646/pull-ci-openshift-ocs-operator-master-ocs-operator-e2e-aws/1287737204793151488) | `/test ocs-operator-e2e-aws`\nci/prow/verify-latest-csv | caeb07ab06f1996856e8b41122ac4261218dd0ef | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/openshift_ocs-operator/646/pull-ci-openshift-ocs-operator-master-verify-latest-csv/1287847507321163776) | `/test verify-latest-csv`\nci/prow/ocs-operator-ci | caeb07ab06f1996856e8b41122ac4261218dd0ef | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/openshift_ocs-operator/646/pull-ci-openshift-ocs-operator-master-ocs-operator-ci/1287847507241472000) | `/test ocs-operator-ci`\nci/prow/red-hat-storage-ocs-ci-e2e-aws | caeb07ab06f1996856e8b41122ac4261218dd0ef | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/openshift_ocs-operator/646/pull-ci-openshift-ocs-operator-master-red-hat-storage-ocs-ci-e2e-aws/1287847507300192256) | `/test red-hat-storage-ocs-ci-e2e-aws`\n\n[Full PR test history](https://prow.ci.openshift.org/pr-history?org=openshift&repo=ocs-operator&pr=646). [Your PR dashboard](https://prow.ci.openshift.org/pr?query=is:pr+state:open+author:rajatsingh25aug).\n\n<details>\n\nInstructions for interacting with me using PR comments are available [here](https://git.k8s.io/community/contributors/guide/pull-requests.md).  If you have questions or suggestions related to my behavior, please file an issue against the [kubernetes/test-infra](https://github.com/kubernetes/test-infra/issues/new?title=Prow%20issue:) repository. I understand the commands that are listed [here](https://go.k8s.io/bot-commands).\n</details>\n<!-- test report -->',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-27T20:50:17Z',
#   'org': {'id': 792337,
#    'login': 'openshift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openshift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/792337?'}},
#  {'id': '13029781276',
#   'type': 'PushEvent',
#   'actor': {'id': 37060772,
#    'login': 'Virteip',
#    'display_login': 'Virteip',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Virteip',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37060772?'},
#   'repo': {'id': 279311320,
#    'name': 'Virteip/holbertonschool-csharp',
#    'url': 'https://api.github.com/repos/Virteip/holbertonschool-csharp'},
#   'payload': {'push_id': 5439438337,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4810ee5552ef1ef535a6794556f80536ac4ce5d5',
#    'before': 'abe61a541b27c83f69b44ea0b2d5009e1a05a27a',
#    'commits': [{'sha': '4810ee5552ef1ef535a6794556f80536ac4ce5d5',
#      'author': {'email': 'sergiopietri@gmail.com', 'name': 'Virteip'},
#      'message': '[Add]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Virteip/holbertonschool-csharp/commits/4810ee5552ef1ef535a6794556f80536ac4ce5d5'}]},
#   'public': True,
#   'created_at': '2020-07-27T20:50:17Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"58e009550aac31001185ed12","text":"The oldest cat video on YouTube dates back to 1894.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e008340aac31001185ecfb","text":"Cats sleep 70% of their lives.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"599f87db9a11040c4a16343f","text":"The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5894af975cdc7400113ef7f9","text":"The technical term for a cat’s hairball is a bezoar.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5b0c5e3e7ab3c50014df65fe","text":"People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"58e00a000aac31001185ed15","text":"Female cats are typically right-pawed while male cats are typically left-pawed.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e00a1a0aac31001185ed18","text":"Cats and humans have nearly identical sections of the brain that control emotion.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e0088b0aac31001185ed09","text":"The world\'s largest cat measured 48.5 inches long.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"58e00a7e0aac31001185ed19","text":"A cat\'s cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog\'s 160 million.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"58e00b1f0aac31001185ed1e","text":"In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"5b01a447c6914f0014cc9a30","text":"The special sensory organ called the Jacobson\'s organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat\'s nasal cavity and is located on the roof of their mouth behind their teeth.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"5b1b4055841d9700146158d3","text":"Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58 ...

# %%
import json

json.loads(r.text)
# Out:
# {'all': [{'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009550aac31001185ed12',
#    'text': 'The oldest cat video on YouTube dates back to 1894.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e008340aac31001185ecfb',
#    'text': 'Cats sleep 70% of their lives.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a000aac31001185ed15',
#    'text': 'Female cats are typically right-pawed while male cats are typically left-pawed.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e0088b0aac31001185ed09',
#    'text': "The world's largest cat measured 48.5 inches long.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece7253a0d2ec00178ae28c',
#    'type': 'cat',
#    'text': 'Cat is cat.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece9fa9a0d2ec00178ae28e',
#    'type': 'cat',
#    'text': 'Z.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ed11e643c15f700172e3856',
#    'type': 'cat',
#    'text': 'Los gatos tienen más huesos que los seres humanos, nos ganan por 24.',
#    'user': {'_id': '5ed11e353c15f700172e3855',
#     'name': {'first': 'Luciano', 'last': 'Garrido Sepulveda'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eddfb501ed5570017aaf3b9',
#    'type': 'cat',
#    'text': 'Take a try.',
#    'user': {'_id': '5eddfb351ed5570017aaf3b8',
#     'name': {'first': 'calix', 'last': 'cheng'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eebc851515a030017471024',
#    'type': 'cat',
#    'text': 'Cats are cats.',
#    'user': {'_id': '5eebc848515a030017471023',
#     'name': {'first': 'Ricky', 'last': 'Chon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef556dff61f300017030d4c',
#    'type': 'cat',
#    'text': 'Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.',
#    'user': {'_id': '5e1a9b981fd6150015fa736f',
#     'name': {'first': 'Andrew', 'last': 'Pobrica'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef5bbdbf61f300017030d4f',
#    'type': 'cat',
#    'text': 'Fdfd.',
#    'user': {'_id': '5ef5bbcdf61f300017030d4e',
#     'name': {'first': 'Touch', 'last': 'Akhil'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0371215ac1ed0017c647a9',
#    'type': 'cat',
#    'text': 'Cxcbc.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f03712d5ac1ed0017c647aa',
#    'type': 'cat',
#    'text': 'Jfhfhf.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0a15090fc09b00174aec96',
#    'type': 'cat',
#    'text': '1123405258.',
#    'user': {'_id': '5f0a15010fc09b00174aec95',
#     'name': {'first': 'nelson enrique', 'last': 'redondo b'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f119d925ada6000174e785c',
#    'type': 'cat',
#    'text': 'Cat are cute.',
#    'user': {'_id': '5f119d3e5ada6000174e785b',
#     'name': {'first': 'Prof', 'last': 'MATH DZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
