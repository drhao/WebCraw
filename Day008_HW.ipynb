# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://cdn.amplitude.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')
print(r)
print(type(r))
#是http的Response物件，用BeautifulSoup
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <Response [200]>
# <class 'requests.models.Response'>

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
#因為是html
#處理後是BeeutifulSoup物件'bs4.BeautifulSoup'
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, "html5lib")
print(soup)
print(type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link crossorigin="true" href="https://www.googletagmanager.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://certify.alexametrics.com" rel="dns-prefetch"/><link href="https://cloudfront-labs.amazonaws.com" rel="dns-prefetch"/><link href="https://cdn.amplitude.com" rel="dns-prefetch"/><link href="https://bilanx.dcard.tw" rel="dns-prefetch"/><link href="https://imgur.dcard.tw" rel="dns-prefetch"/><link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/><link href="https://browser.sentry-cdn.com" rel="dns-prefetch"/><link href="https://gcs.dcard.tw" rel="dns-prefetch"/><link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><link href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/st ...
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category" property="al:ios:url"/><script type="application/ld+json">{"@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/><link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/><link as="script" href="/_next/static/1746e7f66ff93fbc0f51b059fbe24xyf3ab3b3fc/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/1746e7f66ff93fbc0f51b059fbe24xyf3ab3b3fc/pages/forum.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.11af5d57638529689fb7.js" rel="preload"/><link as="script" href="/_next/static/chunks/f11c1c9ca307549248c22f336a06a8470faa9437.51d5aa58c95c376403b9.js" rel="preload"/><link as="script" href="/_next/static/chunks/9733ad4fcf4e360bea91e88bd275e284bd541816.9ef68d9669bcf8d5e4e9.js" rel="preload"/><link as="script" href="/_next/static/chunks/e3739aa3b0f3ab92604692f96965e4792539a4c0.08ee7996db7676dc7f54.js" rel="preload"/><link as="script" href="/_next/static/chunks/107.ebd10ce0b882aa611b29.js" rel="preload"/><link as="script" href="/_next/static/chunks/4146d37fbdfcf7615748222089b374359ea5cf8e.c3d2a535ad7ef63b034d.js" rel="preload"/><link as="script" href="/_next/static/chunks/03f40cdcc4858ba3cd07fb2f8443c0308d535c64.ca83ffd25fda8e176680.js" rel="preload"/><link as="script" href="/_next/static/chunks/181.8345ac2cbf6470a1fcf8.js" rel="preload"/><link as="script" href="/_next/static/chunks/151.86dd6409acc05dc76400.js" rel="preload"/><link as="script" href="/_next/static/chunks/fe8bb93dcba62e8ce8a062d724dbc8a69309bd57.c19b9afc62ad7daf60bd.js" rel="preload"/><link as="script" href="/_next/static/chunks/126.d777705585d5c4f2c237.js" rel="preload"/><link as="script" href="/_next/static/chunks/211.135da054b75275b0592b.js" rel="preload"/><link as="script" href="/_next/static/chunks/128.d12eab9dd56ac852e69f.js" rel="preload"/><link as="script" href="/_next/static/runtime/webpack-1f8ec3652730b1d74d7e.js" rel="preload"/><link as="script" href="/_next/static/chunks/framework.d191055f266dc7aaae69.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.11af5d57638529689fb7.js" rel="preload"/><link as="script" href="/_next/static/chunks/f11c1c9ca307549248c22f336a06a8470faa9437.51d5aa58c95c376403b9.js" rel="preload"/><link as="script" href="/_next/static/chunks ...
# .fwHxVQ img,.fwHxVQ svg{height:100%;width:100%;}/*!sc*/
# .cRCIzY{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .cRCIzY img,.cRCIzY svg{height:100%;width:100%;}/*!sc*/
# .jbfjNp{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .jbfjNp img,.jbfjNp svg{height:100%;width:100%;}/*!sc*/
# .ggXXCl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .ggXXCl img,.ggXXCl svg{height:100%;width:100%;}/*!sc*/
# .kWUEba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .kWUEba img,.kWUEba svg{height:100%;width:100%;}/*!sc*/
# data-styled.g1[id="sc-1rm1ozc-0"]{content:"fwHxVQ,cRCIzY,jbfjNp,ggXXCl,kWUEba,"}/*!sc*/
# .jPisqW{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g2[id="ih5c0o-0"]{content:"jPisqW,"}/*!sc*/
# .dBqPat{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;width:100%;margin-left:px;}/*!sc*/
# data-styled.g4[id="ih5c0o-2"]{content:"dBqPat,"}/*!sc*/
# .hHuYAw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;height:40px;padding:10px 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-size:16px;line-height:normal;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .hHuYAw::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g6[id="ih5c0o-4"]{content:"hHuYAw,"}/*!sc*/
# .krYaWn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .krYaWn form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g9[id="sc-1ehu1w3-0"]{content:"krYaWn,"}/*!sc*/
# .evDMiH{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 10px;font-size:14px;color:#fff;}/*!sc*/
# .evDMiH::-webkit-search-cancel-button{display:none;}/*!sc*/
# .evDMiH::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g11[id="sc-1ehu1w3-2"]{content:"evDMiH,"}/*!sc*/
# .bGWEMw{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g12[id="sc-1ehu1w3-3"]{content:"bGWEMw,"}/*!sc*/
# .lbIsud{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g17[id="ffo8iu-0"]{content:"lbIsud,"}/*!sc*/
# .iFzsWx{position:relative;background-color:#fff;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .iFzsWx:hover{color:rgba(0,0,0,1);}/*!sc*/
# .iFzsWx::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .gOZCQi{position:relative;background-color:#fff;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .gOZCQi:hover{color:rgba(0,0,0,1);}/*!sc*/
# .gOZCQi::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g18[id="ffo8iu-1"]{content:"iFzsWx,gOZCQi,"}/*!sc*/
# .gPEpjI{background-color:#3397cf !important;}/*!sc*/
# data-styled.g38[id="sc-10brrpi-0"]{content:"gPEpjI,"}/*!sc*/
# .kKaGuz{border-radius:50%;overflow:hidden;}/*!sc*/
# data-styled.g40[id="sc-1heqsqc-0"]{content:"kKaGuz,"}/*!sc*/
# .cobkEp{background:#006ea5;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}/*!sc*/
# .kDKEON{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g41[id="sc-1heqsqc-1"]{content:"cobkEp,kDKEON,"}/*!sc*/
# .qPACF{position:relative;height:120px;padding:16px 0;width:100%;}/*!sc*/
# data-styled.g78[id="sc-8n4pv8-0"]{content:"qPACF,"}/*!sc*/
# .gKDILJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# data-styled.g80[id="sc-1kuvyve-0"]{content:"gKDILJ,"}/*!sc*/
# .bpnvkI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# data-styled.g81[id="sc-1kuvyve-1"]{content:"bpnvkI,"}/*!sc*/
# .gPmczY{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;}/*!sc*/
# .gPmczY:first-child{margin-left:0;}/*!sc*/
# data-styled.g82[id="sc-1kuvyve-2"]{content:"gPmczY,"}/*!sc*/
# .bIYJbX{padding-left:6px;}/*!sc*/
# data-styled.g83[id="sc-1kuvyve-3"]{content:"bIYJbX,"}/*!sc*/
# .dNvklZ{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}/*!sc*/
# data-styled.g90[id="sc-1szhyqg-0"]{content:"dNvklZ,"}/*!sc*/
# .ctfFF{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g91[id="sc-1szhyqg-1"]{content:"ctfFF,"}/*!sc*/
# .kZxHwn{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g92[id="sc-1szhyqg-2"]{content:"kZxHwn,"}/*!sc*/
# .GtocX{grid-column:mainRight / end;}/*!sc*/
# data-styled.g93[id="sc-1szhyqg-3"]{content:"GtocX,"}/*!sc*/
# .bImJhr{margin:0 12px;min-height:calc(100vh - 68px);min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g94[id="sc-9fdzn5-0"]{content:"bImJhr,"}/*!sc*/
# .kbYpwI{height:100%;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g95[id="sc-9fdzn5-1"]{content:"kbYpwI,"}/*!sc*/
# .hHrnvN{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .hRWyAp{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g97[id="sc-17x0g9b-0"]{content:"hHrnvN,hRWyAp,"}/*!sc*/
# .cugsgk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# data-styled.g98[id="sc-17x0g9b-1"]{content:"cugsgk,"}/*!sc*/
# .ixTrsr{display:block;height:100%;}/*!sc*/
# data-styled.g101[id="ezgous-0"]{content:"ixTrsr,"}/*!sc*/
# .cOWxiB{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g102[id="sc-1h3w01r-0"]{content:"cOWxiB,"}/*!sc*/
# .emWQsw{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g103[id="sc-1ccznvc-0"]{content:"emWQsw,"}/*!sc*/
# .fXrMZE{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g104[id="sc-1ccznvc-1"]{content:"fXrMZE,"}/*!sc*/
# .iDvOMF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g105[id="sc-1ccznvc-2"]{content:"iDvOMF,"}/*!sc*/
# .kClVql{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g108[id="sc-4hbl5y-0"]{content:"kClVql,"}/*!sc*/
# .cMYlHL{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g125[id="sc-1tslx79-0"]{content:"cMYlHL,"}/*!sc*/
# .bHsDKc .msew01-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g126[id="n5x8h7-0"]{content:"bHsDKc,"}/*!sc*/
# .kNKMUy{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g127[id="sc-18hjmuk-0"]{content:"kNKMUy,"}/*!sc*/
# .lgXNYK{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g128[id="sc-18hjmuk-1"]{content:"lgXNYK,"}/*!sc*/
# .ivXMtf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g165[id="eygvu1-0"]{content:"ivXMtf,"}/*!sc*/
# .dfooky{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g166[id="eygvu1-1"]{content:"dfooky,"}/*!sc*/
# .kwFGxe{display:block;border:0;width:100%;height:130px;overflow:hidden;}/*!sc*/
# data-styled.g169[id="wk6ojg-0"]{content:"kwFGxe,"}/*!sc*/
# .eLxCoI{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .eLxCoI >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g177[id="oboeui-0"]{content:"eLxCoI,"}/*!sc*/
# .iEJVZC{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g179[id="sc-1x63gba-1"]{content:"iEJVZC,"}/*!sc*/
# .cFDYxL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .cFDYxL:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g180[id="m096xq-0"]{content:"cFDYxL,"}/*!sc*/
# .gIRboB{position:relative;}/*!sc*/
# .gIRboB::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g184[id="gpcsqh-0"]{content:"gIRboB,"}/*!sc*/
# .UapXH{position:relative;width:100%;height:100%;}/*!sc*/
# data-styled.g185[id="sc-4rlot1-0"]{content:"UapXH,"}/*!sc*/
# .dOnrba{position:absolute;top:0;left:0;bottom:0;right:0;}/*!sc*/
# data-styled.g186[id="sc-4rlot1-1"]{content:"dOnrba,"}/*!sc*/
# .fpGTbc{box-sizing:border-box;}/*!sc*/
# data-styled.g188[id="sc-4rlot1-3"]{content:"fpGTbc,"}/*!sc*/
# .cqPjit{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);left:0;bottom:0;height:var(--track-size);width:100%;}/*!sc*/
# .cqPjit:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g191[id="sc-4rlot1-6"]{content:"cqPjit,"}/*!sc*/
# .flcklM{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);width:var(--track-size);height:100%;top:0;right:0;}/*!sc*/
# .flcklM:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g192[id="sc-4rlot1-7"]{content:"flcklM,"}/*!sc*/
# .krgPcu{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);height:var(--thumb-size);margin:var(--thumb-margin) 0;}/*!sc*/
# .sc-4rlot1-0:hover .krgPcu{opacity:1;}/*!sc*/
# .sc-4rlot1-5:hover .krgPcu{height:var(--track-size);margin:0;}/*!sc*/
# data-styled.g194[id="sc-4rlot1-9"]{content:"krgPcu,"}/*!sc*/
# .OeTYC{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);width:var(--thumb-size);margin:0 var(--thumb-margin);}/*!sc*/
# .sc-4rlot1-0:hover .OeTYC{opacity:1;}/*!sc*/
# .sc-4rlot1-5:hover .OeTYC{width:var(--track-size);margin:0;}/*!sc*/
# data-styled.g195[id="sc-4rlot1-10"]{content:"OeTYC,"}/*!sc*/
# .euHYSq{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g196[id="sc-1xg2zzw-0"]{content:"euHYSq,"}/*!sc*/
# .cJhOtt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;position:relative;}/*!sc*/
# data-styled.g197[id="sc-1xg2zzw-1"]{content:"cJhOtt,"}/*!sc*/
# .jSnabR{position:relative;}/*!sc*/
# data-styled.g292[id="upagim-0"]{content:"jSnabR,"}/*!sc*/
# body{background-color:#00324e;}/*!sc*/
# data-styled.g312[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .jysJzd{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g314[id="sc-15kv3jb-0"]{content:"jysJzd,"}/*!sc*/
# .eobiuS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g326[id="sc-6oxm01-0"]{content:"eobiuS,"}/*!sc*/
# .cuMsby{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g327[id="sc-6oxm01-1"]{content:"cuMsby,"}/*!sc*/
# .hiTIMq{color:rgba(0,0,0,.6);}/*!sc*/
# .hiTIMq:not(:last-child)::after{content:'·';padding:0 0.5em;}/*!sc*/
# data-styled.g328[id="sc-6oxm01-2"]{content:"hiTIMq,"}/*!sc*/
# .hQpPh{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g329[id="sc-6oxm01-3"]{content:"hQpPh,"}/*!sc*/
# .McoWn{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g334[id="t5f2fb-0"]{content:"McoWn,"}/*!sc*/
# .klhxjz{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g335[id="qtg15c-0"]{content:"klhxjz,"}/*!sc*/
# .dKXZJX{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g336[id="qtg15c-1"]{content:"dKXZJX,"}/*!sc*/
# .idhNkN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .idhNkN:last-child{padding-right:0;}/*!sc*/
# data-styled.g337[id="qtg15c-2"]{content:"idhNkN,"}/*!sc*/
# .eVtVFc{padding-right:8px;}/*!sc*/
# data-styled.g338[id="qtg15c-3"]{content:"eVtVFc,"}/*!sc*/
# .gXSRDf{position:relative;z-index:1;}/*!sc*/
# data-styled.g339[id="qtg15c-4"]{content:"gXSRDf,"}/*!sc*/
# .lmtfq{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 8px auto 12px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g340[id="sc-1v1d5rx-0"]{content:"lmtfq,"}/*!sc*/
# .jokhD{font-size:14px;grid-area:header;overflow:hidden;}/*!sc*/
# data-styled.g341[id="sc-1v1d5rx-1"]{content:"jokhD,"}/*!sc*/
# .kZjhSU{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g342[id="sc-1v1d5rx-2"]{content:"kZjhSU,"}/*!sc*/
# .kPUUNB{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .kPUUNB::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g343[id="sc-1v1d5rx-3"]{content:"kPUUNB,"}/*!sc*/
# .iCLomy{font-size:14px;color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g344[id="sc-1v1d5rx-4"]{content:"iCLomy,"}/*!sc*/
# .jgRMFX{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g345[id="sc-1v1d5rx-5"]{content:"jgRMFX,"}/*!sc*/
# .gamvcw{margin-right:6px;}/*!sc*/
# data-styled.g346[id="sc-1v1d5rx-6"]{content:"gamvcw,"}/*!sc*/
# .kCzfnz{padding:0 60px;}/*!sc*/
# data-styled.g350[id="sc-1gvwjik-0"]{content:"kCzfnz,"}/*!sc*/
# .jUsrZG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;white-space:nowrap;}/*!sc*/
# data-styled.g600[id="wzbfyd-0"]{content:"jUsrZG,"}/*!sc*/
# .gdsbju{border-left:1px solid rgb(222,222,222);padding-right:10px;height:30px;}/*!sc*/
# data-styled.g601[id="wzbfyd-1"]{content:"gdsbju,"}/*!sc*/
# .iCyCDQ{cursor:pointer;border:none;background:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0;height:100%;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;outline:none;}/*!sc*/
# data-styled.g602[id="wzbfyd-2"]{content:"iCyCDQ,"}/*!sc*/
# .fREDbe{margin-left:2px;}/*!sc*/
# data-styled.g604[id="wzbfyd-4"]{content:"fREDbe,"}/*!sc*/
# .loYKtF{color:rgba(0,0,0,.35);padding:0 5px;}/*!sc*/
# data-styled.g605[id="wzbfyd-5"]{content:"loYKtF,"}/*!sc*/
# .eGZZaJ{color:#3397cf;padding-left:2px;}/*!sc*/
# data-styled.g606[id="wzbfyd-6"]{content:"eGZZaJ,"}/*!sc*/
# .hGybZb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g607[id="sc-1llawk3-0"]{content:"hGybZb,"}/*!sc*/
# .bsQBQI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .bsQBQI > *{height:100%;width:100%;}/*!sc*/
# data-styled.g608[id="sc-1llawk3-1"]{content:"bsQBQI,"}/*!sc*/
# .MpCYW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# data-styled.g609[id="sc-1llawk3-2"]{content:"MpCYW,"}/*!sc*/
# .lboGbm{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;border-radius:4px 4px 0 0;border-bottom:1px solid rgba(0,0,0,0.15);position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;}/*!sc*/
# data-styled.g611[id="tylbbx-1"]{content:"lboGbm,"}/*!sc*/
# .lnjwXY{width:100%;z-index:1;}/*!sc*/
# data-styled.g617[id="tylbbx-7"]{content:"lnjwXY,"}/*!sc*/
# .bgurqB{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g618[id="sc-19z7wht-0"]{content:"bgurqB,"}/*!sc*/
# </style></head><body><div id="__next"><div class="sc-18hjmuk-0 kNKMUy"><div class="sc-1ccznvc-0 emWQsw"><div class="sc-1ccznvc-1 fXrMZE"><a class="sc-1h3w01r-0 cOWxiB" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ixTrsr" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/></a><div class="sc-18hjmuk-1 lgXNYK"><div class="sc-1ehu1w3-0 krYaWn"><form><label class="ih5c0o-0 jPisqW"><div class="ih5c0o-2 dBqPat"><input aria-label="搜尋" class="ih5c0o-4 hHuYAw sc-1ehu1w3-2 evDMiH" placeholder="搜尋" type="search" value=""/></div></label><button class="sc-1ehu1w3-3 bGWEMw" disabled="" title="搜尋" type="submit"><span class="sc-1rm1ozc-0 fwHxVQ sc-1ehu1w3-7 bvbdhI" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button></form></div></div></div><div class="sc-1ccznvc-2 iDvOMF" role="navigation"><a class="sc-17x0g9b-0 hHrnvN sc-4hbl5y-0 kClVql" href="/signup" role="button"><span class="sc-17x0g9b-1 cugsgk">註冊 / 登入</span></a><div class="sc-1tslx79-0 cMYlHL"><a class="sc-17x0g9b-0 hRWyAp" role="button" title="更多"><span class="sc-17x0g9b-1 cugsgk"><span class="sc-1rm1ozc-0 cRCIzY sc-17x0g9b-2 hVYFOL" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="sc-1szhyqg-0 dNvklZ"><div class="sc-1szhyqg-1 ctfFF"><div class="sc-1xg2zzw-0 euHYSq"><a href="/forum/all"><div class="m096xq-0 cFDYxL"><div class="sc-1xg2zzw-1 cJhOtt"><span class="sc-1rm1ozc-0 cRCIzY sc-1xg2zzw-2 pbJgK" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="sc-1x63gba-1 iEJVZC">所有看板</div></div></a><a href="/forum/popular"><div class="m096xq-0 cFDYxL"><div class="sc-1xg2zzw-1 cJhOtt"><span class="sc-1rm1ozc-0 cRCIzY sc-1xg2zzw-2 pbJgK" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="sc-1x63gba-1 iEJVZC">即時熱門看板</div></div></a><a href="/goods"><div class="m096xq-0 cFDYxL"><div class="sc-1xg2zzw-1 cJhOtt"><span class="sc-1rm1ozc-0 cRCIzY gpcsqh-0 gIRboB" fill="#fff" role="img" size="24"><svg viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></div><div class="sc-1x63gba-1 iEJVZC">好物研究室</div></div></a><div class ...
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'
}

r = requests.get(url, headers = headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, "html5lib")
print(soup)
print(type(soup))
# Out:
# <!DOCTYPE html>
# <html data-hairline="true" data-theme="light" lang="zh"><head><meta charset="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="webkit" name="renderer"/><meta content="webkit" name="force-rendering"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" name="google-site-verification"/><meta content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的优质内容，基于问答的内容生产方式和独特的社区机制，吸引、聚集了各行各业中大量的亲历者、内行人、领域专家、领域爱好者，将高质量的内容透过人的节点来成规模地生产和分享。用户通过问答等交流方式建立信任和连接，打造和提升个人影响力，并发现、获得新机会。" name="description" property="og:description"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.67c7b278.png" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-120.b3e6278d.png" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-76.7a750095.png" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-60.a4a761d4.png" rel="apple-touch-icon" sizes="60x60"/><link href="https://static.zhihu.com/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://static.zhihu.com/static/search.xml" rel="search" title="知乎" type="application/opensearchdescription+xml"/><link href="//static.zhimg.com" rel="dns-prefetch"/><link href="//pic1.zhimg.com" rel="dns-prefetch"/><link href="//pic2.zhimg.com" rel="dns-prefetch"/><link href="//pic3.zhimg.com" rel="dns-prefetch"/><link href="//pic4.zhimg.com" rel="dns-prefetch"/><style>
# .u-safeAreaInset-top {
#   height: constant(safe-area-inset-top) !important;
#   height: env(safe-area-inset-top) !important;
#
# }
# .u-safeAreaInset-bottom {
#   height: constant(safe-area-inset-bottom) !important;
#   height: env(safe-area-inset-bottom) !important;
#
# }
# </style><link href="https://static.zhihu.com/heifetz/main.app.216a26f4.ef20c1231551323442c2.css" rel="stylesheet"/><link href="https://static.zhihu.com/heifetz/main.explore-routes.216a26f4.e7d68216f75cccef71af.css" rel="stylesheet"/><script crossorigin="anonymous" data-sentry-config="{&quot;dsn&quot;:&quot;https://2d8d764432cc4f6fb3bc78ab9528299d@crash2.zhihu.com/1224&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;301-35c1ac28&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;Loading chunk&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can't find variable: webkit&quot;,&quot;Can't find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;UploadError&quot;,&quot;无法 fetch&quot;,&quot;draft-js&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}" defer="" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js"></script></head><body><div id="root"><div><div class="LoadingBar"></div><div><header class="Sticky AppHeader" data-za-module="TopNavBar" role="banner"><div class="AppHeader-inner"><a aria-label="知乎" href="//www.zhihu.com"><svg fill="#0084FF" height="30" viewBox="0 0 200 91" width="64"><path d="M53.29 80.035l7.32.002 2.41 8.24 13.128-8.24h15.477v-67.98H53.29v67.978zm7.79-60.598h22.756v53.22h-8.73l-8.718 5.473-1.587-5.46-3.72-.012v-53.22zM46.818 43.162h-16.35c.545-8.467.687-16.12.687-22.955h15.987s.615-7.05-2.68-6.97H16.807c1.09-4.1 2.46-8.332 4.1-12.708 0 0-7.523 0-10.085 6.74-1.06 2.78-4.128 13.48-9.592 24.41 1.84-.2 7.927-.37 11.512-6.94.66-1.84.785-2.08 1.605-4.54h9.02c0 3.28-.374 20.9-.526 22.95H6.51c-3.67 0-4.863 7.38-4.863 7.38H22.14C20.765 66.11 13.385 79.24 0 89.62c6.403 1.828 12.784-.29 15.937-3.094 0 0 7.182-6.53 11.12-21.64L43.92 85.18s2.473-8.402-.388-12.496c-2.37-2.788-8.768-10.33-11.496-13.064l-4.57 3.627c1.363-4.368 2.183-8.61 2.46-12.71H49.19s-.027-7.38-2.372-7.38zm128.752-.502c6.51-8.013 14.054-18.302 14.054-18.302s-5.827-4.625-8.556-1.27c-1.874 2.548-11.51 15.063-11.51 15.063l6.012 4.51zm-46.903-18.462c-2.814-2.577-8.096.667-8.096.667s12.35 17.2 12.85 17.953l6.08-4.29s-8.02-11.752-10.83-14.33zM199.99 46.5c-6.18 0-40.908.292-40.953.292v-31.56c1.503 0 3.882-.124 7.14-.376 12.773-.753 21.914-1.25 27.427-1.504 0 0 3.817-8.496-.185-10.45-.96-.37-7.24 1.43-7.24 1.43s-51.63 5.153-72.61 5.64c.5 2.756 2.38 5.336 4.93 6.11 4.16 1.087 7.09.53 15.36.277 7.76-.5 13.65-.76 17.66-.76v31.19h-41.71s.88 6.97 7.97 7.14h33.73v22.16c0 4.364-3.498 6.87-7.65 6.6-4.4.034-8.15-.36-13.027-.566.623 1.24 1.977 4.496 6.035 6.824 3.087 1.502 5.054 2.053 8.13 2.053 9.237 0 14.27-5.4 14.027-14.16V53.93h38.235c3.026 0 2.72-7.432 2.72-7.432z" fill-rule="evenodd"></path></svg></a><ul class="Tabs AppHeader-Tabs" role="navigation"><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/">首页</a></li><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink is-active" data-za-not-track-link="true" href="//www.zhihu.com/explore">发现</a></li><li class="Tabs-item AppHeader-Tab Tabs-item--noMeta" role="tab"><a class="Tabs-link AppHeader-TabsLink" data-za-not-track-link="true" href="//www.zhihu.com/question/waiting">等你来答</a></li></ul><div class="SearchBar" data-za-module="PresetWordItem" role="search"><div class="SearchBar-toolWrapper"><form class="SearchBar-tool"><div><div class="Popover"><label class="SearchBar-input  ...
# <class 'bs4.BeautifulSoup'>
